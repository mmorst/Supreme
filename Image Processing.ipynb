# %% [markdown]
# # Morsy

# %% [markdown]
# ## Import and Display of an Image (labels and scale added)

# %%
from PIL import Image # PIL for PILLOW is the package that allows for importing images.
import numpy as np
import matplotlib.pyplot as plt
img = Image.open("C:\\Users\\User\\Downloads\\speckle_one.png", "r" )

# %matplotlib inline
dx_m = 1*10**-6  #pixel size in meter
Dx_m = 1e-3      #image full size
extent = (-Dx_m/2 * 1e6, +Dx_m/2 * 1e6, -Dx_m/2 * 1e6, +Dx_m/2 * 1e6) 
plt.imshow(img, extent = extent)
plt.xlabel('Horizontal Position [um]')
plt.ylabel('Vertical Positon [um]')
plt.title('My First Speckle :)')
plt.show()

# %% [markdown]
# ## Fourier Transform of the Image

# %%
#real_axis = x_s
#fs = 1/(real_axis[1]-real_axis[0])
#Nfft=len(real_axis)
            
#df = fs/Nfft
#f_cpm = np.linspace(0,(fs-df),Nfft) - (fs-np.mod(Nfft,2)*df)/2

# %%
# %matplotlib inline
data = np.asarray(img) # Converts the image into a numpy array
Y = np.fft.fftshift(np.fft.fft2(data))  # it rearranges the fourier transform to make it symetrical about zero
plt.imshow(np.abs(Y)**0.1)
plt.show()

# %% [markdown]
# # Image processing (Raw)

# %%
from PIL import Image # PIL for PILLOW is the package that allows for importing images.
import numpy as np
import matplotlib.pyplot as plt
#from scipy import toimage
#from scipy.misc import toimage

img = Image.open("C:\\Users\\User\\Downloads\\speckle_one.png", "r" ) #This line imports the image and assign it to variable img
                                                                            # Note Syntax: The path must be in double quotes,
                                                                            # use double back-slash, and add , "r"
#Y = np.fft.fft(img)
#toimage(Y).show()
#print(Y)
width, height = img.size                                                                                     

print(type(img))

#print(Y)
#y = Image.fromarray(Y)
# Out:
# <class 'PIL.PngImagePlugin.PngImageFile'>

# %%
# %matplotlib notebook
dx_m = 1*10**-6  #pixel size in meter
Dx_m = 1e-3      #image full size
extent = (-Dx_m/2 * 1e6, +Dx_m/2 * 1e6, -Dx_m/2 * 1e6, +Dx_m/2 * 1e6) 
plt.imshow(img, extent = extent)
plt.xlabel('Horizontal Position [um]')
plt.ylabel('Vertical Positon [um]')
plt.title('My First Speckle :)')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
data = np.asarray(img) # Converts the image into a numpy array
Y = np.fft.fftshift(np.fft.fft2(data))  # it rearranges the fourier transform to make it symetrical about zero
plt.imshow(np.abs(Y)**0.1)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
