# %% [markdown]
# # How to use a jupyter notebook efficiently

# %% [markdown]
# It is good to get accustomed with how jupyter notebooks operate

# %% [markdown]
# ## Execute a cell

# %% [markdown]
# just highlight the cell and press `shift+return`. Try it here:

# %%
print('I can press shift+return')
# Out:
# I can press shift+return

# %% [markdown]
# ## Enter command mode

# %% [markdown]
# When a cell is active, just push 'ESC'; the cell will become blue and you can make a lot of fun stuff

# %%
#try here

# %% [markdown]
# ## Get help on Jupyter shortcuts

# %% [markdown]
# go on any cell, enter command mode and press the letter `h`

# %%
#try here!

# %% [markdown]
# ## Create markdown cell

# %% [markdown]
# Enter command mode ('ESC') and press the letter `m`

# %% [markdown]
# ## Create a new cell below

# %% [markdown]
# go to command mode, and press letter `b`

# %% [markdown]
# ## Cell magic

# %% [markdown]
# You can modify the behaviour of cells when executed.

# %%
# %%capture
# any console output will not be displayed
print('test')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot(range(3))
plt.show()

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
plt.plot(range(3))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
# %time
#profiling
# Out:
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 5.01 µs

# %%
# %timeit

# %% [markdown]
# #### load an existing python script with `%load script.py`

# %%
# %load test.py
